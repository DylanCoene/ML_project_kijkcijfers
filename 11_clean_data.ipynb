# %%
from datetime import datetime, timedelta
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Cleaning

# %%
kijkcijfers = pd.read_csv('./data2/processed/kijkcijfers_weerdata.csv')
kijkcijfers['timestamp'] = pd.to_datetime(kijkcijfers['timestamp'])
kijkcijfers.sample(5)
# Out:
#                 timestamp  year  month  day  day_of_week  hour channel  \
# 43519 2022-10-10 18:10:59  2022     10   10            0    18     EEN
# 50709 2023-10-08 19:00:05  2023     10    8            6    19   VRT 1
# 36288 2021-10-12 18:21:44  2021     10   12            1    18     VTM
# 43900 2022-10-29 12:59:38  2022     10   29            5    12     VTM
# 31436 2021-02-11 20:41:45  2021      2   11            3    20     VTM
#
#                   program  duration_sec  viewers  ...  precipitation  rain  \
# 43519     DAGELIJKSE KOST        921.00   314581  ...           0.00  0.00
# 50709  HET 7 UUR-JOURNAAL      1,617.00   842207  ...           0.00  0.00
# 36288                LISA      1,454.00   371269  ...           0.00  0.00
# 43900      NIEUWS 13U VTM      1,570.00   173822  ...           0.00  0.00
# 31436        WAT EEN JAAR      3,121.00   253732  ...           0.00  0.00
#
#        snowfall  cloudcover  windspeed_10m  weather_code_daily  \
# 43519      0.00       14.00          14.90               51.00
# 50709      0.00      100.00           6.50                3.00
# 36288      0.00       28.00          15.60               61.00
# 43900      0.00      100.00          12.10                3.00
# 31436      0.00        0.00          12.40                3.00
#
#        wind_speed_10m_max           sunrise            sunset  \
# 43519               18.90  2022-10-10T07:58  2022-10-10T19:02
# 50709               14.20  2023-10-08T07:54  2023-10-08T19:06
# 36288               20.90  2021-10-12T08:02  2021-10-12T18:57
# 43900               17.40  2022-10-29T08:30  2022-10-29T18:23
# 31436               16.50  2021-02-11T09:02  2021-02-11T18:52
#
#       daylight_duration
# 43519         39,828.28
# 50709         40,349.11
# 36288         39,306.91
# 43900         35,575.55
# 31436         35,342.52
#
# [5 rows x 22 columns]

# %% [markdown]
# Check voor null rijen

# %%
print(f"Aantal null-rows: \n{kijkcijfers.isnull().sum()}")
# Out:
# Aantal null-rows:
# timestamp             0
# year                  0
# month                 0
# day                   0
# day_of_week           0
# hour                  0
# channel               0
# program               0
# duration_sec          0
# viewers               0
# temperature_2m        0
# weather_code          0
# precipitation         0
# rain                  0
# snowfall              0
# cloudcover            0
# windspeed_10m         0
# weather_code_daily    0
# wind_speed_10m_max    0
# sunrise               0
# sunset                0
# daylight_duration     0
# dtype: int64

# %%
kijkcijfers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61088 entries, 0 to 61087
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           61088 non-null  datetime64[ns]
#  1   year                61088 non-null  int64
#  2   month               61088 non-null  int64
#  3   day                 61088 non-null  int64
#  4   day_of_week         61088 non-null  int64
#  5   hour                61088 non-null  int64
#  6   channel             61088 non-null  object
#  7   program             61088 non-null  object
#  8   duration_sec        61088 non-null  float64
#  9   viewers             61088 non-null  int64
#  10  temperature_2m      61088 non-null  float64
#  11  weather_code        61088 non-null  float64
#  12  precipitation       61088 non-null  float64
#  13  rain                61088 non-null  float64
#  14  snowfall            61088 non-null  float64
#  15  cloudcover          61088 non-null  float64
#  16  windspeed_10m       61088 non-null  float64
#  17  weather_code_daily  61088 non-null  float64
#  18  wind_speed_10m_max  61088 non-null  float64
#  19  sunrise             61088 non-null  object
#  20  sunset              61088 non-null  object
#  21  daylight_duration   61088 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(6), object(4)
# memory usage: 10.3+ MB

# %% [markdown]
# Bekijk de waarden van viewers om te zien of er onrealistische outliers zijn

# %%
pd.options.display.float_format = '{:,.2f}'.format
kijkcijfers['viewers'].describe()
# Out:
# count      61,088.00
# mean      446,035.63
# std       277,972.24
# min        15,887.00
# 25%       229,953.50
# 50%       360,184.50
# 75%       606,251.25
# max     2,494,114.00
# Name: viewers, dtype: float64

# %% [markdown]
# Alles lijkt oke te zijn, geen speciale cleaning nodig
